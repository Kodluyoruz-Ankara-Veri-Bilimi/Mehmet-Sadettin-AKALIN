# %%
#kütüphanelerin import komutu ile yüklenip, as komutu ile kısaltmalarının yazılamsı
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import os
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeClassifier

class ınfo
    #dosyanın okunması
    def __init__(self, data):
        self.data=data
        
        def ınfo(self):
            
        #Datamızdaki ilk 5 satırı okutma
        print(self.data.head(5))
        
        #Datamızdaki son (n) satırı okutma
        print(self.data.tail())
        
        #Datanın veri tipini görüntüleme
        print(self.data.dtypes)
        
        #Datamızdaki satır ve sütunların kontrolü 
        print(self.data.columns)  
        print(self.data.axes)
        
        #Datanın kaç satır ve sütundan oluştuğunu gösterme
        print(self.data.shape)
        
        #Data hakkında bilgileri almak için
        print(self.data.info())

        #Data hakkında bilgileri almak için
        print(self.data.info())
        
        #Datanın belirli özelliklere göre açıklamasını çıkarma
        print (self.data.describe())
        
      

    
    
class Visualizer():
    #Verilerin farklı formattaki grafikler yardımıyla görselleştirilmesi
    def __init__(self):
        pass
    def histogram(self):
        pass
    def boxplot(self):
        pass
    def Bubbleplot(self):
        pass
    def heatmap(self):
        pass
    def scatter(self):
        pass
    def Piechart(self):
        pass
    def countplot(self):
        pass
    def barplot(self):
        pass
    def subplots(self):
        pass
    def linecharts(self):
        pass  
    def mapplots(self):
        pass  
          
        
        
class PreProcessing():
    # Verilerin ön işlenmesi, temizlenmesi
    def __init__(self):
            
    def cleaning(self):
        
    def fillna(self):
        
    def dropna(self):
        
    # Kategorik değişkenler için işlemler.
    
    def LabelEncoder(self):
        
    def OneHotEncoder(self):
        
    def DummyEncoding(self):
        
    def FeatureScaling(self):
        
 
 class model():
        #Unsupervised Modeller
        class clustering (self)
          def __init__(self):
        
    def KMeans(n_cluster,n_init=10):
        
    def C_Result(self):
        
    def GaussianMixtureModel(self):
        
        
        #Supervised Modeller (lineer,decisiontrees,..)
        class classification (self)
          def __init__(self):
        
    def KNeighborsRegressor(self):
        
    def RandomForestRegressor(self): 
        
    def DecisionTreeClassifier(self):
        
    def Cl_Results(self):
        

        
class Gridsearch():
    # Modelin sonucu (Parametrelere göre analiz yapılması)
    def __init__(self):
        
    def show_result(self):
        
        def predplot(self):
        
        def confusion(self):
